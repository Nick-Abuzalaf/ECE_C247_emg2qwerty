# %% [markdown]
# ## Setup

# %%
# %cd /home/nabuzalaf/emg2qwerty
# %pwd
# Out:
# /home/nabuzalaf/emg2qwerty
# /home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/nabuzalaf/emg2qwerty'

# %% [markdown]
# ## Training
#
# ### Mel + CNN + LSTM (Negative Latency)

# %%
# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name mel_conv_lstm_nl
# Out:
# [2026-03-13 13:46:47,398][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-13/13-46-47
# [2026-03-13 13:46:47,399][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1']
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/nabuzalaf/emg2qwerty/emg2qwerty/train.py", line 129, in <module>
#     main()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
# ...

# %%
# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 datamodule.label_offset=0.5 --multirun --config-name mel_conv_lstm_nl
# Out:
# [2026-03-13 15:03:18,286][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-13/15-03-18
# [2026-03-13 15:03:18,287][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 datamodule.label_offset=0.5
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1', 'datamodule.label_offset=0.5']
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/nabuzalaf/emg2qwerty/emg2qwerty/train.py", line 129, in <module>
#     main()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
# ...

# %% [markdown]
# ## Testing
#
# ### Mel + CNN + LSTM

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-13/13-46-47/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=48-step\=5880.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  datamodule.label_offset=0.1 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name mel_conv_lstm_nl
  # --multirun
# Out:
# [2026-03-13 16:24:04,521][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-13/15-03-18/job0_datamodule.label_offset\=0.5\,trainer.devices\=1\,user\=single_user/checkpoints/epoch\=21-step\=2640.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  datamodule.label_offset=0.5 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name mel_conv_lstm_nl \
  --multirun
# Out:
# [2026-03-13 16:27:24,441][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-13/16-27-24
# [2026-03-13 16:27:24,442][HYDRA] 	#0 : user=single_user checkpoint=/home/nabuzalaf/emg2qwerty/logs/2026-03-13/15-03-18/job0_datamodule.label_offset\=0.5\,trainer.devices\=1\,user\=single_user/checkpoints/epoch\=21-step\=2640.ckpt train=False trainer.accelerator=gpu datamodule.label_offset=0.5 decoder=ctc_greedy
