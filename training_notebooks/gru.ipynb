# %% [markdown]
# ## Setup

# %%
# %cd /home/nabuzalaf/emg2qwerty
# %pwd
# Out:
# /home/nabuzalaf/emg2qwerty
# /home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/nabuzalaf/emg2qwerty'

# %% [markdown]
# ## Training
#
# ### GRU

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name gru
# Out:
# [2026-03-02 19:34:24,580][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-02/19-34-24
# [2026-03-02 19:34:24,582][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1

# %% [markdown]
# ### CNN + GRU

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name conv_gru
# Out:
# [2026-03-03 20:44:51,993][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-03/20-44-51
# [2026-03-03 20:44:51,995][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1']
# Traceback (most recent call last):
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 466, in <lambda>
#     lambda: hydra.multirun(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/hydra.py", line 162, in multirun
#     ret = sweeper.sweep(arguments=task_overrides)
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/core_plugins/basic_sweeper.py", line 181, in sweep
#     _ = r.return_value
# ...

# %% [markdown]
# ### Mel + CNN + GRU

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name mel_conv_gru
# Out:
# [2026-03-11 22:05:39,656][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-11/22-05-39
# [2026-03-11 22:05:39,658][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1

# %% [markdown]
# ## Testing
#
# ### GRU

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-02/19-34-24/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=49-step\=6000.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name gru
  # --multirun
# Out:
# [2026-03-08 22:40:54,696][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### CNN + GRU

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-03/20-44-51/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=49-step\=6000.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name conv_gru
  # --multirun
# Out:
# [2026-03-08 22:41:35,985][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### Mel + CNN + GRU

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-08/21-10-30/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=49-step\=6000.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name mel_conv_gru
  # --multirun
# Out:
# [2026-03-08 22:44:11,936][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
