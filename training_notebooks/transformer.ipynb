# %% [markdown]
# ## Setup

# %%
# %cd /home/nabuzalaf/emg2qwerty
# %pwd
# Out:
# /home/nabuzalaf/emg2qwerty
# /home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/nabuzalaf/emg2qwerty'

# %% [markdown]
# ## Training
#
# ### Transformer

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name transformer
# Out:
# [2026-03-10 06:27:14,581][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-10/06-27-14
# [2026-03-10 06:27:14,582][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1

# %% [markdown]
# ### CNN + Transformer

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name conv_transformer
# Out:
# [2026-03-09 10:06:17,438][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-09/10-06-17
# [2026-03-09 10:06:17,439][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1']
# Traceback (most recent call last):
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 466, in <lambda>
#     lambda: hydra.multirun(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/hydra.py", line 162, in multirun
#     ret = sweeper.sweep(arguments=task_overrides)
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/core_plugins/basic_sweeper.py", line 181, in sweep
#     _ = r.return_value
# ...

# %% [markdown]
# ### Mel + CNN + Transformer

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name mel_conv_transformer
# Out:
# [2026-03-11 23:37:05,624][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-11/23-37-05
# [2026-03-11 23:37:05,626][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# ^C
# Traceback (most recent call last):
#
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/submitit/local/local.py", line 375, in run
#     exit_codes = self.wait()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/submitit/local/local.py", line 366, in wait
#     time.sleep(1.0 / freq)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/submitit/local/_local.py", line 16, in <module>
# ...

# %% [markdown]
# ## Testing
#
# ### Transformer

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-09/07-40-59/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=48-step\=5880.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name transformer
  # --multirun
# Out:
# [2026-03-09 17:52:42,166][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### CNN + Transformer

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-09/10-06-17/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=22-step\=2760.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name conv_transformer
  # --multirun
# Out:
# [2026-03-09 18:34:25,749][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### Mel + CNN + Transformer

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-09/13-00-31/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=48-step\=5880.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name mel_conv_transformer
  # --multirun
# Out:
# [2026-03-09 19:17:54,755][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
