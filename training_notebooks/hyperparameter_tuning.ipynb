# %% [markdown]
# ## Setup

# %%
# %cd /home/nabuzalaf/emg2qwerty
# %pwd
# Out:
# /home/nabuzalaf/emg2qwerty
# /home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/nabuzalaf/emg2qwerty'

# %% [markdown]
# ## Hyperparameter Tuning
# ### CNN + LSTM

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.1 --multirun --config-name conv_lstm

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.2 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 00:34:21,915][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/00-34-21
# [2026-03-12 00:34:21,916][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.1 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 01:49:14,443][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/01-49-14
# [2026-03-12 01:49:14,444][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.2 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 03:21:34,945][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/03-21-34
# [2026-03-12 03:21:34,947][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.1 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 04:55:41,642][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/04-55-41
# [2026-03-12 04:55:41,644][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.2 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 06:38:52,102][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/06-38-51
# [2026-03-12 06:38:52,104][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.1 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 08:21:14,019][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/08-21-13
# [2026-03-12 08:21:14,021][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.2 --multirun --config-name conv_lstm
# Out:
# [2026-03-12 10:51:04,263][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/10-51-04
# [2026-03-12 10:51:04,265][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.2

# %% [markdown]
# ### Mel + CNN + LSTM

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.1 --multirun --config-name mel_conv_lstm

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.2 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 13:29:52,552][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/13-29-52
# [2026-03-12 13:29:52,554][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.1 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 14:41:48,136][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/14-41-47
# [2026-03-12 14:41:48,138][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.2 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 16:06:59,057][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/16-06-58
# [2026-03-12 16:06:59,058][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.1 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 17:30:08,027][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/17-30-07
# [2026-03-12 17:30:08,029][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.2 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 18:53:08,271][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/18-53-08
# [2026-03-12 18:53:08,272][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.2

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.1 --multirun --config-name mel_conv_lstm
# Out:
# [2026-03-12 20:17:42,233][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-12/20-17-42
# [2026-03-12 20:17:42,235][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.1

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.2 --multirun --config-name mel_conv_lstm

# %% [markdown]
# ### CNN + GRU

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.1 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=2 module.dropout=0.2 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.1 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=256 module.num_layers=4 module.dropout=0.2 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.1 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=2 module.dropout=0.2 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.1 --multirun --config-name conv_gru

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 module.hidden_size=512 module.num_layers=4 module.dropout=0.2 --multirun --config-name conv_gru
