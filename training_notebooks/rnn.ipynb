# %% [markdown]
# ## Setup

# %%
# %cd /home/nabuzalaf/emg2qwerty
# %pwd
# Out:
# /home/nabuzalaf/emg2qwerty
# /home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/nabuzalaf/emg2qwerty'

# %% [markdown]
# ## Training
#
# ### RNN

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name rnn
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/nabuzalaf/emg2qwerty/emg2qwerty/train.py", line 15, in <module>
#     import pytorch_lightning as pl
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/pytorch_lightning/callbacks/__init__.py", line 14, in <module>
#     from pytorch_lightning.callbacks.batch_size_finder import BatchSizeFinder
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/pytorch_lightning/callbacks/batch_size_finder.py", line 24, in <module>
#     from pytorch_lightning.callbacks.callback import Callback
# ...

# %% [markdown]
# ### RNN + CNN

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name conv_rnn
# Out:
# [2026-03-05 05:09:05,911][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-05/05-09-05
# [2026-03-05 05:09:05,913][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1']
# Traceback (most recent call last):
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 466, in <lambda>
#     lambda: hydra.multirun(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/hydra.py", line 162, in multirun
#     ret = sweeper.sweep(arguments=task_overrides)
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/core_plugins/basic_sweeper.py", line 181, in sweep
#     _ = r.return_value
# ...

# %% [markdown]
# ### Mel + CNN + RNN

# %%
# !python -m emg2qwerty.train user="single_user" trainer.accelerator=gpu trainer.devices=1 --multirun --config-name mel_conv_rnn
# Out:
# [2026-03-10 19:35:17,376][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-10/19-35-17
# [2026-03-10 19:35:17,377][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# Error executing job with overrides: ['user=single_user', 'trainer.accelerator=gpu', 'trainer.devices=1']
# Traceback (most recent call last):
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/utils.py", line 466, in <lambda>
#     lambda: hydra.multirun(
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/hydra.py", line 162, in multirun
#     ret = sweeper.sweep(arguments=task_overrides)
#   File "/home/nabuzalaf/emg2qwerty/venv/lib/python3.10/site-packages/hydra/_internal/core_plugins/basic_sweeper.py", line 181, in sweep
#     _ = r.return_value
# ...

# %% [markdown]
# ## Testing
#
# ### RNN

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-02/20-50-46/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=43-step\=5280.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name rnn
  # --multirun
# Out:
# [2026-03-09 21:27:51,473][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### CNN + RNN

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-05/05-09-05/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=49-step\=6000.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name conv_rnn
  # --multirun
# Out:
# [2026-03-09 21:28:31,987][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### Mel + CNN + RNN

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="/home/nabuzalaf/emg2qwerty/logs/2026-03-09/20-33-52/job0_trainer.devices\=1\,user\=single_user/checkpoints/epoch\=47-step\=5760.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  --config-name mel_conv_rnn
  # --multirun
# Out:
# [2026-03-09 21:29:42,555][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
